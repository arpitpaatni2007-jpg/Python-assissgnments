# %%
# Name: Arpit Patni
# Date: 27 Oct 2025
# Project: Daily Calorie Tracker CLI

import datetime

print("Welcome to the Daily Calorie Tracker!")
print("This program helps you check your total calorie intake each day.\n")

# Ask the user for their daily calorie limit
daily_limit = int(input("Enter your daily calorie limit: "))

# Ask how many meals to log
meal_count = int(input("How many meals would you like to log? "))

# Set up lists to store meal names and calories
meal_names = []
calorie_list = []

# Collect meal names and calorie values
for i in range(meal_count):
    meal_name = input("Enter meal name for meal #" + str(i+1) + ": ")
    meal_cal = int(input("Enter calories for " + meal_name + ": "))
    meal_names.append(meal_name)
    calorie_list.append(meal_cal)

# Calculate total and average calories
total_calories = sum(calorie_list)
average_calories = total_calories / meal_count

# Compare with daily limit and display warning if needed
if total_calories > daily_limit:
    print("\nWarning: You have exceeded your daily calorie limit!")
else:
    print("\nGood job! You are within your daily calorie limit.")

# Print a neat summary using tabs and formatting
print("\nCalorie Intake Summary:\n")
print("Meal Name\tCalories")
print("-----------------------------")
for j in range(meal_count):
    print(meal_names[j] + "\t" + str(calorie_list[j]))
print("-----------------------------")
print("Total:\t\t" + str(total_calories))
print("Average:\t" + "{:.2f}".format(average_calories))
print("Limit:\t\t" + str(daily_limit))

# BONUS: Ask to save session log
save_option = input("\nWould you like to save your session log to a file? (yes/no): ")

if save_option.lower() == "yes":
    now = datetime.datetime.now()
    filename = "calorie_log_" + now.strftime("%Y%m%d_%H%M%S") + ".txt"
    with open(filename, "w") as f:
        f.write("Daily Calorie Tracker Session\n")
        f.write("Date and Time: " + now.strftime("%Y-%m-%d %H:%M:%S") + "\n")
        f.write("Daily Calorie Limit: " + str(daily_limit) + "\n")
        f.write("\nMeal Name\tCalories\n")
        for j in range(meal_count):
            f.write(meal_names[j] + "\t" + str(calorie_list[j]) + "\n")
        f.write("\nTotal: " + str(total_calories) + "\n")
        f.write("Average: " + "{:.2f}".format(average_calories) + "\n")
        if total_calories > daily_limit:
            f.write("Status: Exceeded the calorie limit!\n")
        else:
            f.write("Status: Within the calorie limit!\n")
    print("Session log saved as: " + filename)
else:
    print("Session log not saved.")

print("\nThank you for using the Daily Calorie Tracker!")
# Out:
# Welcome to the Daily Calorie Tracker!
# This program helps you check your total calorie intake each day.
# Enter your daily calorie limit:  200
# How many meals would you like to log?  2
# Enter meal name for meal #1:  eggs
# Enter calories for eggs:  80
# Enter meal name for meal #2:  milk
# Enter calories for milk:  100
# Good job! You are within your daily calorie limit.
#
# Calorie Intake Summary:
#
# Meal Name	Calories
# -----------------------------
# eggs	80
# milk	100
# -----------------------------
# Total:		180
# Average:	90.00
# Limit:		200
# Would you like to save your session log to a file? (yes/no):  yes
# Session log saved as: calorie_log_20251110_201454.txt
#
# Thank you for using the Daily Calorie Tracker!
