# %%
from book import Book

b = Book("Test Book", "Test Author", "0001")
print(b)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from book import Book
#       3 b = Book("Test Book", "Test Author", "0001")
#       4 print(b)
#
# ModuleNotFoundError: No module named 'book'
